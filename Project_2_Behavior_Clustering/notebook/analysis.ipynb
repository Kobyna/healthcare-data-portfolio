# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/kobynaebow/Desktop/healthcare-data-portfolio/Project_2_Behavior_Clustering/data/mental-heath-in-tech-2016_20161114.csv")
df
# Out:
#       Are you self-employed?  \
# 0                          0
# 1                          0
# 2                          0
# 3                          1
# 4                          0
# ...                      ...
# 1428                       1
# 1429                       1
# 1430                       0
# 1431                       0
# 1432                       0
#
#      How many employees does your company or organization have?  \
# 0                                                26-100
# 1                                                  6-25
# 2                                                  6-25
# 3                                                   NaN
# 4                                                  6-25
# ...                                                 ...
# 1428                                                NaN
# 1429                                                NaN
# 1430                                            100-500
# ...
